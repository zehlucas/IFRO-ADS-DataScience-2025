# %%
import pandas as pd
df_acidentes = pd.read_csv("../acidentes.csv")
pd.set_option('display.max_columns', None)
# Out:
# C:\Users\zehlu\AppData\Local\Temp\ipykernel_26660\3131093461.py:2: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_acidentes = pd.read_csv("../acidentes.csv")

# %%
df_acidentes.head(10)
# Out:
#    Unnamed: 0  num_acidente   chv_localidade data_acidente uf_acidente  \
# 0       16027       1676690  AC1200401202201    2022-01-21          AC
# 1       16028       4441865  AC1200401202201    2022-01-03          AC
# 2       16029       3797599  AC1200401202201    2022-01-20          AC
# 3       16030       2339226  AC1200401202201    2022-01-23          AC
# 4       16031       3838808  AC1200401202201    2022-01-12          AC
# 5       16032       3200493  AC1200401202201    2022-01-19          AC
# 6       16033       1752444  AC1200807202201    2022-01-19          AC
# 7       16034       1404581  AC1200401202201    2022-01-02          AC
# 8       16035       4176270  AC1200401202201    2022-01-17          AC
# 9       16036       3827407  AC1200401202201    2022-01-18          AC
#
#    ano_acidente  mes_acidente  mes_ano_acidente  codigo_ibge     dia_semana  \
# 0          2022             1             12022      1200401    SEXTA-FEIRA
# ...

# %%
df_acidentes[df_acidentes['mes_acidente'] == 11].head()
# Out:
#       Unnamed: 0  num_acidente   chv_localidade data_acidente uf_acidente  \
# 3155       19182       3658041  AC1200401202211    2022-11-30          AC
# 3156       19183       2358953  AC1200203202211    2022-11-09          AC
# 3157       19184       4244217  AC1200401202211    2022-11-22          AC
# 3158       19185         21235  AC1200401202211    2022-11-21          AC
# 3159       19186       3807608  AC1200203202211    2022-11-17          AC
#
#       ano_acidente  mes_acidente  mes_ano_acidente  codigo_ibge  \
# 3155          2022            11            112022      1200401
# 3156          2022            11            112022      1200203
# 3157          2022            11            112022      1200401
# 3158          2022            11            112022      1200401
# 3159          2022            11            112022      1200203
#
#          dia_semana  ... lim_velocidade       tp_pista  ind_guardrail  \
# ...

# %%
df_acidentes.hora_acidente[0:10]
# Out:
# 0     53400
# 1     93400
# 2    123400
# 3     73400
# 4     43400
# 5    113400
# 6    103400
# 7     53400
# 8    223400
# 9     33400
# Name: hora_acidente, dtype: int64
